# %%
import scipy.io as sio
import numpy as np

# %%
#get the negative data of protein
load_fn = 'PSSM/protein_neg.mat'
load_data = sio.loadmat(load_fn)
#print (load_data)

# %%
#get the name of protein
name=[]
for i in load_data['name'][0]:
    #print (i)
    name.append(''.join(i).split('.')[0])
#print (len(name))
#print (name[0],name[1])
#print (name)

# %%
import pandas as pd
import csv
with open("feature/neg/name_neg.csv","w+",newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(name)

# %% [markdown]
# 通过下面的操作得到负样本的特征值
# feature_Neg.csv文件中有550行（样本个数），120列（特征值）
# 对应每一个负样本

# %%
n=3
features=[]
for pssm in load_data['train_pssm'][0]:
    # get the submatrix 
    L = len(pssm)
    length=int(L/n)
    # the length of L1 and L2
    if(L%n==0):
        L1=L2=length
    else:
        L1=length
        L2=L-L1*(n-1)
    print('L,L1,L2',L,L1,L2)
    # get the first block of feautre F
    feature1=[]
    for k in range(1,n):
        temp_fea=[]
        for j in range(0,20):
            temp=0
            for i in range((k-1)*L1,k*L1):
                temp+=pssm[i][j]
            temp_=temp/L1
            temp_fea.append(temp_)
        feature1.extend(temp_fea)
    #print('feature1......',feature1)
    print('len(feature1):',len(feature1)) #40
    with open("feature/neg/feature1_Neg.csv","a+",newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(feature1)
    feature2=[]
    for k in range(1,n):
        temp_fea=[]
        for j in range(0,20):
            temp=0
            for i in range((k-1)*L1,k*L1-1):
                temp+=(pssm[i][j]-pssm[i+1][j])**2
            temp_=temp/(L1-1)
            temp_fea.append(temp_)
        feature2.extend(temp_fea)
    #print('feature2......',feature2)
    print('len(feature2):',len(feature2)) #40
    with open("feature/neg/feature2_Neg.csv","a+",newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(feature2)
    feature1_n=[]
    for j in range(0,20):
        temp=0
        for i in range((n-1)*L1,(n-1)*L1+L2):
            temp+=pssm[i][j]
        temp_=temp/L2
        feature1_n.append(temp_)
    #print ('feature1_n......',feature1_n)
    print ('len(feature1_n):',len(feature1_n)) #20
    with open("feature/neg/feature1_n_Neg.csv","a+",newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(feature1_n)
    feature2_n=[]
    for j in range(0,20):
        temp=0
        for i in range((n-1)*L1,(n-1)*L1+L2-1):
            temp+=(pssm[i][j]-pssm[i+1][j])**2
        temp_=temp/(L2-1)
        feature2_n.append(temp_)
    #print('feature2_n......',feature2_n)
    print('len(feature2_n):',len(feature2_n)) # 20
    with open("feature/neg/feature2_n_Neg.csv","a+",newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(feature2_n)        
    # get all features
    feature=[]
    feature.extend(feature1) # 40 
    feature.extend(feature2) # 40
    feature.extend(feature1_n) # 20
    feature.extend(feature2_n) # 20
    #print('feature......',feature) 
    print(len(feature)) # 120
    with open("feature/neg/feature_Neg.csv","a+",newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(feature)
    features.append(feature)
#print(features)
print(len(features)) #550
with open("feature/neg/features_Neg.csv","a+",newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(features)
# Out:
# L,L1,L2 413 137 139
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 257 85 87
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 338 112 114
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 305 101 103
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 352 117 118
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 237 79 79
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 446 148 150
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 231 77 77
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 250 83 84
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 150 50 50
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 263 87 89
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 336 112 112
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 142 47 48
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 619 206 207
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 532 177 178
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 517 172 173
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 355 118 119
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 83 27 29
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 154 51 52
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 267 89 89
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 291 97 97
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 523 174 175
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 323 107 109
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 349 116 117
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 99 33 33
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 489 163 163
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 198 66 66
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 401 133 135
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 577 192 193
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 541 180 181
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 402 134 134
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 283 94 95
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 121 40 41
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 298 99 100
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 214 71 72
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 173 57 59
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 316 105 106
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 88 29 30
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 168 56 56
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 122 40 42
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 159 53 53
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 137 45 47
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 227 75 77
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 313 104 105
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 243 81 81
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 155 51 53
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 571 190 191
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 143 47 49
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 260 86 88
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 106 35 36
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 149 49 51
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 122 40 42
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 212 70 72
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2 225 75 75
# len(feature1): 40
# len(feature2): 40
# len(feature1_n): 20
# len(feature2_n): 20
# 120
# L,L1,L2